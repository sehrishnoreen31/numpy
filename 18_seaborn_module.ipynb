# %%
import matplotlib as plt
import numpy as np
import seaborn as sns

# %%
my_array = np.random.choice([3,4,5,4,3], size=100)
my_array
# Out:
# array([3, 5, 4, 4, 4, 4, 3, 3, 5, 4, 5, 3, 4, 5, 3, 4, 5, 4, 4, 4, 4, 4,
#        4, 4, 3, 4, 4, 4, 3, 4, 4, 3, 3, 4, 4, 4, 4, 3, 4, 3, 3, 4, 3, 3,
#        5, 5, 3, 3, 5, 3, 4, 5, 3, 4, 3, 4, 3, 3, 4, 4, 3, 3, 5, 3, 3, 5,
#        5, 5, 4, 3, 3, 4, 4, 3, 5, 4, 3, 5, 4, 5, 3, 4, 4, 4, 3, 4, 4, 5,
#        4, 5, 4, 3, 3, 3, 3, 4, 4, 4, 5, 3])

# %%
sns.displot(my_array)

# %%
sns.displot(my_array, kind='kde')
